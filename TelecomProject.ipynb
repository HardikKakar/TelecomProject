# %%
#TelecomProject

# %%
#Importing the required modules
import pandas as pd
import warnings
warnings.filterwarnings("ignore")
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as sp
from sklearn.preprocessing import Imputer, LabelEncoder, StandardScaler
from sklearn.linear_model import LogisticRegression
import datetime
from sklearn.metrics import accuracy_score, confusion_matrix, f1_score, roc_auc_score, average_precision_score
from sklearn.model_selection import cross_val_score, train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis, QuadraticDiscriminantAnalysis
from sklearn.gaussian_process import GaussianProcessClassifier
import xgboost
# %matplotlib inline

# %%
provideddata = pd.ExcelFile('ProvidedData.xlsx')
active=pd.read_excel(provideddata,sheet_name=0)
churned=pd.read_excel(provideddata,sheet_name=1)

# %%
activedata=active.copy()
churneddata=churned.copy()

# %%
activedata.head()
# Out:
#   SITE_ACCOUNT_NUMBER ACCOUNT_STATUS FIRST_COMMUNICATION_DATE UPGRADE_DATE  \
# 0        AMR-11112345         Active               2001-11-27   2003-12-14
# 1        AMR-14837287         Active               2003-05-02   2006-08-08
# 2        AMR-14837803         Active               2001-01-28   2004-03-17
# 3        AMR-14837821         Active               2001-11-20   2005-03-27
# 4        AMR-14839297         Active               2002-02-27   2004-06-14
#
#   SERVICE_ PLAN    MODEL SALES_CHANNEL DIRECT_INDIRECT_CHANNEL SALES_SOURCE  \
# 0           NaN   HN9000          Vars                Indirect      UNKNOWN
# 1           Pro  HN7000S  Sales Agents                Indirect          NCC
# 2      Power150   HN9000   Call Center                Indirect          NCC
# 3      Power150   DW6000  Sales Agents                  Direct          NaN
# 4          Home  HN7000S   Call Center                Indirect          TAG
#
#   COMPANY_SOURCE_NAME      ...          SITE_TYPE_DESC WARRANTY_NAME  \
# 0       HNS Customers      ...        Broadband Remote             0
# 1       HNS Customers      ...                Spaceway             0
# 2       HNS Customers      ...        Broadband Remote             0
# 3       HNS Customers      ...                Spaceway             0
# 4       HNS Customers      ...        Broadband Remote             0
#
#   MOST_RECENT_SALES_CHANNEL GENDER DATE_OF_BIRTH AGE INCOME MARITAL_STATUS  \
# 0            HN7000 Upgrade    2.0      1-5-1943  69      0            1.0
# 1             Retail           2.0    28-12-1969  43      4            1.0
# 2            National Sales    2.0     20-7-1954  58      4            1.0
# 3                    Direct    NaN     10-5-1990  22      6            1.0
# 4            DW6000 Upgrade    1.0     11-5-1976  36      7            0.0
#
#   PRESENCE_OF_CHILDREN COMPUTER_OWNER
# 0                  0.0              N
# 1                  0.0              N
# 2                  0.0              N
# 3                  1.0            NaN
# 4                  0.0            NaN
#
# [5 rows x 29 columns]

# %%
activedata.describe()
# Out:
#             GENDER  MARITAL_STATUS  PRESENCE_OF_CHILDREN
# count  8728.000000     9680.000000           8684.000000
# mean      1.454056        0.572521              0.235030
# std       0.497913        0.592780              0.424042
# min       1.000000        0.000000              0.000000
# 25%       1.000000        0.000000              0.000000
# 50%       1.000000        1.000000              0.000000
# 75%       2.000000        1.000000              0.000000
# max       2.000000        2.000000              1.000000

# %%
churneddata.head()
# Out:
#   SITE_ACCOUNT_NUMBER ACCOUNT_STATUS FIRST_COMMUNICATION_DATE CHURN_DATE  \
# 0        AMR-53205840         Closed               2002-01-18 2006-04-02
# 1        AMR-53383136         Closed               2002-01-02 2006-07-09
# 2        AMR-53608585         Closed               2002-01-06 2008-12-30
# 3        AMR-53610590         Closed               2002-01-05 2004-08-19
# 4        AMR-53612154         Closed               2002-01-05 2006-08-17
#
#   UPGRADE_DATE  SERVICE_PLAN   MODEL  SALES_CHANNEL DIRECT_INDIRECT_CHANNEL  \
# 0   2004-01-03  Professional  DW6000            NaN                Indirect
# 1   2004-07-28            SO  DW6000  Retail/Others                Indirect
# 2   2005-04-27           NaN  DW6000  Retail/Others                Indirect
# 3          NaT            SO  DW4000            NaN                Indirect
# 4   2005-11-12  Professional  DW7000  Retail/Others                Indirect
#
#        SALES_SOURCE      ...          SITE_TYPE_DESC WARRANTY_NAME  \
# 0        Perfect 10      ...        Broadband Remote           NaN
# 1  ValueElectronics      ...        Broadband Remote           NaN
# 2               TAG      ...        Broadband Remote           NaN
# 3               TAG      ...        Broadband Remote           NaN
# 4        Perfect 10      ...        Broadband Remote           NaN
#
#   MOST_RECENT_SALES_CHANNEL GENDER DATE_OF_BIRTH   AGE INCOME MARITAL_STATUS  \
# 0     Dealer-Generated Sale    2.0    27-10-1964  48.0      0              .
# 1            National Sales    NaN    22-10-1965  47.0      5              0
# 2                    Direct    2.0     20-3-1951  61.0      8              1
# 3                    Direct    1.0     27-3-1948  64.0      0              .
# 4     Dealer-Generated Sale    1.0     25-8-1956  56.0      6              0
#
#   PRESENCE_OF_CHILDREN COMPUTER_OWNER
# 0                  NaN              N
# 1                  0.0              Y
# 2                  0.0              Y
# 3                  NaN              Y
# 4                  0.0              N
#
# [5 rows x 30 columns]

# %%
churneddata.describe()
# Out:
#             GENDER          AGE  PRESENCE_OF_CHILDREN
# count  8762.000000  9992.000000            8748.00000
# mean      1.431408    49.556545               0.38043
# std       0.495301    14.271563               0.48552
# min       1.000000    22.000000               0.00000
# 25%       1.000000    38.000000               0.00000
# 50%       1.000000    50.000000               0.00000
# 75%       2.000000    61.000000               1.00000
# max       2.000000    90.000000               1.00000

# %%
#Dropping Columns

# %%
activedata.drop(['FIRST_COMMUNICATION_DATE','DATE_OF_BIRTH','EMAIL_ADDRESS','ADDRESS','FIRST_NAME','LAST_NAME','ZIPCODE','STATE','CITY','COMPANY_SOURCE_NAME'],axis=1,inplace=True)

# %%
churneddata.drop(['FIRST_COMMUNICATION_DATE','CHURN_DATE','DATE_OF_BIRTH','EMAIL_ADDRESS','ADDRESS','FIRST_NAME','LAST_NAME','ZIPCODE','STATE','CITY','COMPANY_SOURCE_NAME'],axis=1,inplace=True)

# %%
#Determining number of NULL values
activedata.isnull().sum().sort_values(ascending=False)
# Out:
# COMPUTER_OWNER               3055
# SALES_CHANNEL                2906
# FEEDBACK                     1914
# PRESENCE_OF_CHILDREN         1315
# GENDER                       1271
# SERVICE_ PLAN                1239
# WARRANTY_NAME                 957
# SALES_SOURCE                  693
# MODEL                         676
# SATELLITE                     396
# MARITAL_STATUS                319
# INCOME                        318
# DIRECT_INDIRECT_CHANNEL        45
# SITE_TYPE_DESC                 11
# UPGRADE_DATE                   10
# MOST_RECENT_SALES_CHANNEL       7
# AGE                             1
# ACCOUNT_STATUS                  1
# SITE_ACCOUNT_NUMBER             1
# dtype: int64

# %%
#Determining number of NULL values
churneddata.isnull().sum().sort_values(ascending=False)
# Out:
# COMPUTER_OWNER               3243
# SALES_CHANNEL                2602
# FEEDBACK                     2028
# SERVICE_PLAN                 1482
# PRESENCE_OF_CHILDREN         1252
# GENDER                       1238
# SATELLITE                    1013
# UPGRADE_DATE                  879
# DIRECT_INDIRECT_CHANNEL       784
# MODEL                         710
# WARRANTY_NAME                 681
# SALES_SOURCE                  290
# MARITAL_STATUS                281
# SITE_TYPE_DESC                 63
# MOST_RECENT_SALES_CHANNEL      21
# ACCOUNT_STATUS                 15
# AGE                             8
# INCOME                          0
# SITE_ACCOUNT_NUMBER             0
# dtype: int64

# %%
#Fixing the missing values

# %%
columns=['COMPUTER_OWNER','GENDER','FEEDBACK','INCOME','MARITAL_STATUS','MODEL','PRESENCE_OF_CHILDREN','SALES_CHANNEL','SERVICE_ PLAN','SALES_SOURCE','SATELLITE','WARRANTY_NAME']
for i in columns:
    activedata[i]=activedata[i].fillna(activedata[i].mode()[0])

columns=['COMPUTER_OWNER','DIRECT_INDIRECT_CHANNEL','FEEDBACK','GENDER','MARITAL_STATUS','MODEL','PRESENCE_OF_CHILDREN','SALES_CHANNEL','SERVICE_PLAN','SATELLITE','SALES_SOURCE','WARRANTY_NAME']
for i in columns:
    churneddata[i]=churneddata[i].fillna(churneddata[i].mode()[0])

# %%
activedata.isnull().sum().sort_values(ascending=False)
# Out:
# DIRECT_INDIRECT_CHANNEL      45
# SITE_TYPE_DESC               11
# UPGRADE_DATE                 10
# MOST_RECENT_SALES_CHANNEL     7
# SITE_ACCOUNT_NUMBER           1
# ACCOUNT_STATUS                1
# AGE                           1
# SALES_SOURCE                  0
# SERVICE_ PLAN                 0
# MODEL                         0
# SALES_CHANNEL                 0
# COMPUTER_OWNER                0
# FEEDBACK                      0
# PRESENCE_OF_CHILDREN          0
# WARRANTY_NAME                 0
# GENDER                        0
# INCOME                        0
# MARITAL_STATUS                0
# SATELLITE                     0
# dtype: int64

# %%
churneddata.isnull().sum().sort_values(ascending=False)
# Out:
# UPGRADE_DATE                 879
# SITE_TYPE_DESC                63
# MOST_RECENT_SALES_CHANNEL     21
# ACCOUNT_STATUS                15
# AGE                            8
# COMPUTER_OWNER                 0
# SALES_SOURCE                   0
# SERVICE_PLAN                   0
# MODEL                          0
# SALES_CHANNEL                  0
# DIRECT_INDIRECT_CHANNEL        0
# SATELLITE                      0
# FEEDBACK                       0
# PRESENCE_OF_CHILDREN           0
# WARRANTY_NAME                  0
# GENDER                         0
# INCOME                         0
# MARITAL_STATUS                 0
# SITE_ACCOUNT_NUMBER            0
# dtype: int64

# %%
# Renaming Column 'SERVICE_ PLAN' to 'SERVICE_PLAN' to maintain same column name in both the tables
activedata.rename(columns={'SERVICE_ PLAN':'SERVICE_PLAN'},inplace=True)

# %%
#Defining the super table "data" which will contain records from both the tables; active as well as churned
data=activedata.copy()

# %%
data.index=data['SITE_ACCOUNT_NUMBER']

# %%
data.columns
# Out:
# Index(['SITE_ACCOUNT_NUMBER', 'ACCOUNT_STATUS', 'UPGRADE_DATE', 'SERVICE_PLAN',
#        'MODEL', 'SALES_CHANNEL', 'DIRECT_INDIRECT_CHANNEL', 'SALES_SOURCE',
#        'FEEDBACK', 'SATELLITE', 'SITE_TYPE_DESC', 'WARRANTY_NAME',
#        'MOST_RECENT_SALES_CHANNEL', 'GENDER', 'AGE', 'INCOME',
#        'MARITAL_STATUS', 'PRESENCE_OF_CHILDREN', 'COMPUTER_OWNER'],
#       dtype='object')

# %%
churneddata.index=churneddata["SITE_ACCOUNT_NUMBER"]

# %%
data=pd.concat([data,churneddata])

# %%
data['UPGRADE_STATUS']=0
data.update(data[data["UPGRADE_DATE"].isnull()==False].UPGRADE_STATUS.replace(0,1))

# %%
data.drop(columns='UPGRADE_DATE')
# Out:
#                     SITE_ACCOUNT_NUMBER ACCOUNT_STATUS       SERVICE_PLAN  \
# SITE_ACCOUNT_NUMBER
# AMR-11112345               AMR-11112345         Active            Proplus
# AMR-14837287               AMR-14837287         Active                Pro
# AMR-14837803               AMR-14837803         Active           Power150
# AMR-14837821               AMR-14837821         Active           Power150
# AMR-14839297               AMR-14839297         Active               Home
# AMR-14840229               AMR-14840229         Active                Pro
# AMR-14841940               AMR-14841940         Active           Power150
# AMR-14842501               AMR-14842501         Active           Power150
# AMR-14847927               AMR-14847927         Active               Home
# AMR-14859335               AMR-14859335         Active          Basic_Ltd
# AMR-14859461               AMR-14859461         Active              Basic
# AMR-14864530               AMR-14864530         Active            Proplus
# AMR-14866461               AMR-14866461         Active           Power150
# AMR-14873604               AMR-14873604         Active          Basic_Ltd
# AMR-14873868               AMR-14873868         Active              Basic
# AMR-14875244               AMR-14875244         Active           Power150
# AMR-14875495               AMR-14875495         Active            Proplus
# AMR-14876904               AMR-14876904         Active               Home
# AMR-14882497               AMR-14882497         Active              Elite
# AMR-14902253               AMR-14902253         Active            Proplus
# AMR-14903035               AMR-14903035         Active          Basic_Ltd
# AMR-14905877               AMR-14905877         Active          Basic_Ltd
# AMR-14905924               AMR-14905924         Active               Home
# AMR-14908151               AMR-14908151         Active              Basic
# AMR-14915157               AMR-14915157         Active               Home
# AMR-14916700               AMR-14916700         Active              Basic
# AMR-14922119               AMR-14922119         Active          Basic_Ltd
# AMR-14923151               AMR-14923151         Active           Power150
# AMR-14925390               AMR-14925390         Active              Basic
# AMR-14928358               AMR-14928358         Active               Home
# ...                                 ...            ...                ...
# Q-94824513                   Q-94824513         Closed          Basic_Ltd
# Q-94825803                   Q-94825803         Closed                Pro
# Q-94826227                   Q-94826227         Closed       Professional
# Q-94828593                   Q-94828593         Closed              Basic
# Q-94849221                   Q-94849221         Closed              Elite
# Q-94850500                   Q-94850500         Closed               Home
# Q-94850883                   Q-94850883         Closed              Elite
# Q-94851198                   Q-94851198         Closed              Basic
# Q-94853567                   Q-94853567         Closed               Home
# Q-94858664                   Q-94858664         Closed          Basic_Ltd
# Q-94860449                   Q-94860449         Closed              Elite
# Q-94862172                   Q-94862172         Closed              Basic
# Q-94864011                   Q-94864011         Closed              Basic
# Q-94867268                   Q-94867268         Closed              Basic
# Q-94882115                   Q-94882115         Closed       Professional
# Q-94886073                   Q-94886073         Closed              Basic
# Q-94891737                   Q-94891737         Closed                Pro
# Q-94892338                   Q-94892338         Closed              Basic
# Q-94899704                   Q-94899704         Closed              Basic
# Q-94902971                   Q-94902971         Closed                Pro
# Q-94907809                   Q-94907809         Closed              Elite
# Q-94912671                   Q-94912671         Closed            Proplus
# Q-94924989                   Q-94924989         Closed              Elite
# Q-94940213                   Q-94940213         Closed              Basic
# Q-94943846                   Q-94943846         Closed              Elite
# Q-94945717                   Q-94945717         Closed              Basic
# Q-94977539                   Q-94977539         Closed  Professional Plus
# T000078824                   T000078824         Closed               Home
# T000079618                   T000079618         Closed            Power15
# T000080092                   T000080092         Closed  Professional Plus
#
#                        MODEL  SALES_CHANNEL DIRECT_INDIRECT_CHANNEL  \
# SITE_ACCOUNT_NUMBER
# AMR-11112345          HN9000           Vars                Indirect
# AMR-14837287         HN7000S   Sales Agents                Indirect
# AMR-14837803          HN9000    Call Center                Indirect
# AMR-14837821          DW6000   Sales Agents                  Direct
# AMR-14839297         HN7000S    Call Center                Indirect
# AMR-14840229          HN9000   Sales Agents                Indirect
# AMR-14841940         HN7000S   Sales Agents                Indirect
# AMR-14842501         HN7000S           Vars                Indirect
# AMR-14847927          DW6000           Vars                Indirect
# AMR-14859335         HN7000S   Sales Agents                Indirect
# AMR-14859461         HN7000S    Call Center                Indirect
# AMR-14864530         HN7000S   Sales Agents                  Direct
# AMR-14866461         HN7000S     Web orders                Indirect
# AMR-14873604          DW6000           Vars                Indirect
# AMR-14873868         HN7000S   Sales Agents                Indirect
# AMR-14875244         HN7000S  Retail/others                Indirect
# AMR-14875495          DW4020    Call Center                Indirect
# AMR-14876904             UNK           Vars                Indirect
# AMR-14882497         HN7000S    Call Center                Indirect
# AMR-14902253          DW4020    Call Center                Indirect
# AMR-14903035          HN9000  Retail/others                Indirect
# AMR-14905877          DW6000   Sales Agents                Indirect
# AMR-14905924         HN7000S     Web orders                Indirect
# AMR-14908151         HN7000S   Sales Agents                Indirect
# AMR-14915157          DW4020   Sales Agents                Indirect
# AMR-14916700         HN7000S           Vars                  Direct
# AMR-14922119          HN9000     Web orders                Indirect
# AMR-14923151          HN9000   Sales Agents                Indirect
# AMR-14925390          HN9000  Retail/others                Indirect
# AMR-14928358         HN7000S   Sales Agents                Indirect
# ...                      ...            ...                     ...
# Q-94824513            HN9000   Sales Agents                  Direct
# Q-94825803           HN7000S   Call Centers                Indirect
# Q-94826227            DW7000   Call Centers                  Direct
# Q-94828593           HN7000S   Sales Agents                  Direct
# Q-94849221            HN9000   Call Centers                Indirect
# Q-94850500            HN9000   Sales Agents                Indirect
# Q-94850883            DW7000  Retail/Others                Indirect
# Q-94851198            HN9000   Call Centers                Indirect
# Q-94853567            DW7000     Web Orders                Indirect
# Q-94858664            HN9000   Call Centers                Indirect
# Q-94860449            HN9000  Retail/Others                Indirect
# Q-94862172            HN9000   Call Centers                  Direct
# Q-94864011            HN9000   Call Centers                Indirect
# Q-94867268            HN9000   Call Centers                Indirect
# Q-94882115            DW6000  Retail/Others                Indirect
# Q-94886073            HN9000           Vars                Indirect
# Q-94891737           HN7000S   Call Centers                Indirect
# Q-94892338            HN9000   Call Centers                Indirect
# Q-94899704            HN9000           Vars                Indirect
# Q-94902971           HN7000S     Web Orders                Indirect
# Q-94907809            HN9000   Sales Agents                Indirect
# Q-94912671            DW6000   Call Centers                Indirect
# Q-94924989            HN9000   Call Centers                  Direct
# Q-94940213           HN7000S   Call Centers                Indirect
# Q-94943846            HN9000   Call Centers                  Direct
# Q-94945717            HN9000   Call Centers                Indirect
# Q-94977539            DW6000  Retail/Others                  Direct
# T000078824            DW4000  Retail/Others                Indirect
# T000079618            DW6000   Call Centers                Indirect
# T000080092           HN7000S   Call Centers                Indirect
#
#                                                 SALES_SOURCE FEEDBACK  \
# SITE_ACCOUNT_NUMBER
# AMR-11112345                                         UNKNOWN     GOOD
# AMR-14837287                                             NCC     GOOD
# AMR-14837803                                             NCC      BAD
# AMR-14837821                                             TAG     GOOD
# AMR-14839297                                             TAG     GOOD
# AMR-14840229                                         UNKNOWN     GOOD
# AMR-14841940                                ValueElectronics     GOOD
# AMR-14842501                                             TAG     GOOD
# AMR-14847927                                             TAG     GOOD
# AMR-14859335                                Hughes Web Order      BAD
# AMR-14859461                                             TAG     GOOD
# AMR-14864530                                        InfoDish      BAD
# AMR-14866461                                        InfoDish      BAD
# AMR-14873604                                Hughes Web Order      BAD
# AMR-14873868                                            NRTC     GOOD
# AMR-14875244                                            RS&I     GOOD
# AMR-14875495                                        InfoDish      BAD
# AMR-14876904                                Hughes Web Order      BAD
# AMR-14882497                                        InfoDish      BAD
# AMR-14902253                                Hughes Web Order      BAD
# AMR-14903035                           Verisign Web Ordering     GOOD
# AMR-14905877                                Hughes Web Order     GOOD
# AMR-14905924                                 ACS Pre-Install     GOOD
# AMR-14908151                   LiveBridge Communications LLC     GOOD
# AMR-14915157                                            RS&I     GOOD
# AMR-14916700                                             TAG     GOOD
# AMR-14922119                                      Perfect 10      BAD
# AMR-14923151                                     AmericanSat     GOOD
# AMR-14925390                                     AmericanSat     GOOD
# AMR-14928358                                        Best Buy     GOOD
# ...                                                      ...      ...
# Q-94824513                                              RS&I      BAD
# Q-94825803                           GoDish.com Ltd LLP (SA)      BAD
# Q-94826227                                  Hughes Web Order      BAD
# Q-94828593                            OKS Ameridial Inc (CC)      BAD
# Q-94849221                      Valley Satellite (RSI561377)     GOOD
# Q-94850500                 American Satellite & Ent Inc (SA)     GOOD
# Q-94850883                     LiveBridge Communications LLC      BAD
# Q-94851198           Satellite Dish Marketing LLC dba Digita      BAD
# Q-94853567                           Electronic Express (SA)     GOOD
# Q-94858664                    DialAmerica Marketing Inc (CC)     GOOD
# Q-94860449                                               TAG      BAD
# Q-94862172                  Communication Solutions LLC (CC)     GOOD
# Q-94864011                    DialAmerica Marketing Inc (CC)     GOOD
# Q-94867268                     LiveBridge Communications LLC      BAD
# Q-94882115                                        Perfect 10      BAD
# Q-94886073                            OKS Ameridial Inc (CC)      BAD
# Q-94891737               EBN Financial dba Dish Systems (SA)     GOOD
# Q-94892338             Professional Technical Services (P10)     GOOD
# Q-94899704                            OKS Ameridial Inc (CC)     GOOD
# Q-94902971                                               TAG      BAD
# Q-94907809                     Direct SAT Broadband LLC (SA)     GOOD
# Q-94912671           Elite Satellite and Home Theater Inc (S      BAD
# Q-94924989                            OKS Ameridial Inc (CC)      BAD
# Q-94940213                    DialAmerica Marketing Inc (CC)      BAD
# Q-94943846                                               TAG      BAD
# Q-94945717                             Red Ventures LLC (SA)     GOOD
# Q-94977539                  Communication Solutions LLC (CC)      BAD
# T000078824                                               TAG      BAD
# T000079618                                               TAG      BAD
# T000080092                                               TAG      BAD
#
#                        SATELLITE    SITE_TYPE_DESC  \
# SITE_ACCOUNT_NUMBER
# AMR-11112345           SPACEWAY3  Broadband Remote
# AMR-14837287         HZN2-VER-4K          Spaceway
# AMR-14837803         SM5-VER-15K  Broadband Remote
# AMR-14837821           SPACEWAY3          Spaceway
# AMR-14839297                   0  Broadband Remote
# AMR-14840229           SPACEWAY3  Broadband Remote
# AMR-14841940          G17-HOR-2K  Broadband Remote
# AMR-14842501          SM5-VER-5K  Broadband Remote
# AMR-14847927         AM6-HOR-21K  Broadband Remote
# AMR-14859335          G17-HOR-6K  Broadband Remote
# AMR-14859461         G3C-VER-24K  Broadband Remote
# AMR-14864530                   0  Broadband Remote
# AMR-14866461         SM5-VER-15K  Broadband Remote
# AMR-14873604           SPACEWAY3  Broadband Remote
# AMR-14873868         HZN-HOR-19K  Broadband Remote
# AMR-14875244         SM5-VER-15K  Broadband Remote
# AMR-14875495         AM9-VER-2K   Broadband Remote
# AMR-14876904         AM9-VER-2K           Spaceway
# AMR-14882497         SM5-VER-15K  Broadband Remote
# AMR-14902253          SM5-VER-7K  Broadband Remote
# AMR-14903035         SM5-HOR-14K          Spaceway
# AMR-14905877           SPACEWAY3  Broadband Remote
# AMR-14905924          HZN-HOR-8K  Broadband Remote
# AMR-14908151         AM9-HOR-21K  Broadband Remote
# AMR-14915157         AM9-VER-2K   Broadband Remote
# AMR-14916700           SPACEWAY3          Spaceway
# AMR-14922119          G17-HOR-6K          Spaceway
# AMR-14923151           SPACEWAY3  Broadband Remote
# AMR-14925390          G17-HOR-6K  Broadband Remote
# AMR-14928358          G17-HOR-2K  Broadband Remote
# ...                          ...               ...
# Q-94824513             SPACEWAY3  Broadband Remote
# Q-94825803           G26-HOR-14K          Spaceway
# Q-94826227           AM6-HOR-21K          Spaceway
# Q-94828593           SM6-HOR-10K          Spaceway
# Q-94849221             SPACEWAY3  Broadband Remote
# Q-94850500           G3C-VER-24K  Broadband Remote
# Q-94850883            HZN-HOR-8K          Spaceway
# Q-94851198            AMC-VER-5K          Spaceway
# Q-94853567           G3C-VER-24K  Broadband Remote
# Q-94858664             SPACEWAY3  Broadband Remote
# Q-94860449            HZN-HOR-8K  Broadband Remote
# Q-94862172           G3C-VER-24K          Spaceway
# Q-94864011            AMC-VER-5K          Spaceway
# Q-94867268           SM6-HOR-10K  Broadband Remote
# Q-94882115           G16-VER-15K          Spaceway
# Q-94886073            AMC-VER-5K          Spaceway
# Q-94891737             SPACEWAY3  Broadband Remote
# Q-94892338           G28-HOR-16K          Spaceway
# Q-94899704           G28-HOR-16K          Spaceway
# Q-94902971             SPACEWAY3  Broadband Remote
# Q-94907809             SPACEWAY3  Broadband Remote
# Q-94912671           AM6-HOR-21K          Spaceway
# Q-94924989           AM9-HOR-17K          Spaceway
# Q-94940213             SPACEWAY3  Broadband Remote
# Q-94943846           HZN-VER-23K  Broadband Remote
# Q-94945717           G28-HOR-16K          Spaceway
# Q-94977539           G28-HOR-10K          Spaceway
# T000078824             SPACEWAY3  Broadband Remote
# T000079618             SPACEWAY3  Broadband Remote
# T000080092             SPACEWAY3  Broadband Remote
#
#                                      WARRANTY_NAME MOST_RECENT_SALES_CHANNEL  \
# SITE_ACCOUNT_NUMBER
# AMR-11112345                                     0            HN7000 Upgrade
# AMR-14837287                                     0             Retail
# AMR-14837803                                     0            National Sales
# AMR-14837821                                     0                    Direct
# AMR-14839297                                     0            DW6000 Upgrade
# AMR-14840229                                     0            HN9000 Upgrade
# AMR-14841940                                     0                    Retail
# AMR-14842501                                     0             Retail
# AMR-14847927                                     0            HN9000 Upgrade
# AMR-14859335                                     0            HN7000 Upgrade
# AMR-14859461                                     0       DPC Classic upgrade
# AMR-14864530                                     0       DPC Classic upgrade
# AMR-14866461                                     0     Dealer-Generated Sale
# AMR-14873604                                     0       DPC Classic upgrade
# AMR-14873868                                     0                    Direct
# AMR-14875244                                     0                    Direct
# AMR-14875495                                     0       DPC Classic upgrade
# AMR-14876904                                     0         Classic Migration
# AMR-14882497                                     0             Retail
# AMR-14902253                                     0            DW7000 Upgrade
# AMR-14903035                                     0                    Direct
# AMR-14905877                                     0            DW6000 Upgrade
# AMR-14905924                                     0            HN9000 Upgrade
# AMR-14908151                  EXPRESS REPAIR BASIC                    Direct
# AMR-14915157                                     0             Retail
# AMR-14916700                                     0             Retail
# AMR-14922119                                     0                    Retail
# AMR-14923151                                     0            DW6000 Upgrade
# AMR-14925390                                     0     Dealer-Generated Sale
# AMR-14928358                                     0     Dealer-Generated Sale
# ...                                            ...                       ...
# Q-94824513                    EXPRESS REPAIR BASIC       Hughes Sales Agents
# Q-94825803           EXPRESS REPAIR HOME WITH TERM       Hughes Sales Agents
# Q-94826227                    EXPRESS REPAIR BASIC                    Direct
# Q-94828593                                       0                    Direct
# Q-94849221                                       0       Hughes Sales Agents
# Q-94850500                 SRVC ASSUR STD NEW CUST                    Direct
# Q-94850883                                       0     Dealer - Direct Order
# Q-94851198                                       0                    Direct
# Q-94853567                    EXPRESS REPAIR BASIC            Used Equipment
# Q-94858664                    EXPRESS REPAIR BASIC       Hughes Sales Agents
# Q-94860449                                       0                    Direct
# Q-94862172                                       0            DW6000 Upgrade
# Q-94864011                                       0                    Direct
# Q-94867268                    EXPRESS REPAIR BASIC       Hughes Sales Agents
# Q-94882115                                       0                    Direct
# Q-94886073                                       0     Dealer - Direct Order
# Q-94891737                                       0            DW6000 Upgrade
# Q-94892338                                       0                    Direct
# Q-94899704                    EXPRESS REPAIR BASIC            Used Equipment
# Q-94902971                                       0       Hughes Sales Agents
# Q-94907809                                       0            Used Equipment
# Q-94912671                                       0       Hughes Sales Agents
# Q-94924989                    EXPRESS REPAIR BASIC                    Direct
# Q-94940213                    EXPRESS REPAIR BASIC       Hughes Sales Agents
# Q-94943846                                       0       Hughes Sales Agents
# Q-94945717                    EXPRESS REPAIR BASIC                    Direct
# Q-94977539           EXPRESS REPAIR HOME WITH TERM                    Direct
# T000078824                                       0     Dealer - Direct Order
# T000079618                                       0                    Direct
# T000080092                                       0                    Direct
#
#                      GENDER AGE INCOME MARITAL_STATUS  PRESENCE_OF_CHILDREN  \
# SITE_ACCOUNT_NUMBER
# AMR-11112345            2.0  69      0              1                   0.0
# AMR-14837287            2.0  43      4              1                   0.0
# AMR-14837803            2.0  58      4              1                   0.0
# AMR-14837821            1.0  22      6              1                   1.0
# AMR-14839297            1.0  36      7              0                   0.0
# AMR-14840229            2.0  51      7              1                   0.0
# AMR-14841940            1.0  56      3              1                   0.0
# AMR-14842501            1.0  57      7              0                   0.0
# AMR-14847927            2.0  42      4              2                   0.0
# AMR-14859335            2.0  34      4              2                   1.0
# AMR-14859461            2.0  54      3              1                   1.0
# AMR-14864530            1.0  57      6              1                   0.0
# AMR-14866461            2.0  52      A              0                   0.0
# AMR-14873604            1.0  39      6              0                   0.0
# AMR-14873868            1.0  24      6              0                   0.0
# AMR-14875244            1.0  45      7              1                   0.0
# AMR-14875495            1.0   .      0              0                   0.0
# AMR-14876904            1.0  62      0              0                   0.0
# AMR-14882497            2.0  64      5              1                   0.0
# AMR-14902253            2.0  30      C              1                   0.0
# AMR-14903035            1.0  68      9              0                   0.0
# AMR-14905877            2.0  63      0              1                   1.0
# AMR-14905924            2.0  33      6              0                   0.0
# AMR-14908151            1.0  51      0              1                   0.0
# AMR-14915157            1.0   .      0              0                   0.0
# AMR-14916700            1.0  23      D              0                   0.0
# AMR-14922119            2.0  58      7              1                   1.0
# AMR-14923151            2.0  57      4              1                   0.0
# AMR-14925390            2.0  50      0              2                   0.0
# AMR-14928358            1.0  43      4              0                   0.0
# ...                     ...  ..    ...            ...                   ...
# Q-94824513              1.0  32      B              0                   0.0
# Q-94825803              1.0  63      0              1                   1.0
# Q-94826227              1.0  72      7              0                   0.0
# Q-94828593              1.0  45      8              .                   0.0
# Q-94849221              2.0  30      6              1                   1.0
# Q-94850500              2.0  46      5              .                   0.0
# Q-94850883              1.0  46      0              1                   1.0
# Q-94851198              2.0  67      0              1                   1.0
# Q-94853567              1.0  35      5              .                   0.0
# Q-94858664              2.0  35      1              0                   0.0
# Q-94860449              1.0  61      8              0                   0.0
# Q-94862172              1.0  64      0              .                   1.0
# Q-94864011              1.0  40      0              1                   1.0
# Q-94867268              2.0  61      6              .                   1.0
# Q-94882115              2.0  61      6              1                   0.0
# Q-94886073              2.0  53      3              .                   0.0
# Q-94891737              1.0  59      5              1                   1.0
# Q-94892338              1.0  65      0              .                   1.0
# Q-94899704              2.0  70      9              0                   0.0
# Q-94902971              1.0  68      3              1                   1.0
# Q-94907809              2.0  43      4              1                   0.0
# Q-94912671              2.0  40      3              .                   0.0
# Q-94924989              1.0  66      0              1                   1.0
# Q-94940213              1.0  49      3              0                   0.0
# Q-94943846              1.0  28      9              0                   0.0
# Q-94945717              2.0  49      3              .                   1.0
# Q-94977539              2.0  38      2              1                   1.0
# T000078824              2.0  67      8              0                   0.0
# T000079618              1.0  63      0              .                   0.0
# T000080092              1.0  43      0              .                   0.0
#
#                     COMPUTER_OWNER  UPGRADE_STATUS
# SITE_ACCOUNT_NUMBER
# AMR-11112345                     N             1.0
# AMR-14837287                     N             1.0
# AMR-14837803                     N             1.0
# AMR-14837821                     N             1.0
# AMR-14839297                     N             1.0
# AMR-14840229                     N             1.0
# AMR-14841940                     N             1.0
# AMR-14842501                     Y             1.0
# AMR-14847927                     N             1.0
# AMR-14859335                     N             1.0
# AMR-14859461                     N             1.0
# AMR-14864530                     N             1.0
# AMR-14866461                     Y             1.0
# AMR-14873604                     Y             1.0
# AMR-14873868                     N             1.0
# AMR-14875244                     N             1.0
# AMR-14875495                     N             1.0
# AMR-14876904                     Y             1.0
# AMR-14882497                     N             1.0
# AMR-14902253                     N             1.0
# AMR-14903035                     N             1.0
# AMR-14905877                     N             1.0
# AMR-14905924                     N             1.0
# AMR-14908151                     N             1.0
# AMR-14915157                     N             1.0
# AMR-14916700                     N             1.0
# AMR-14922119                     N             1.0
# AMR-14923151                     N             1.0
# AMR-14925390                     N             1.0
# AMR-14928358                     N             1.0
# ...                            ...             ...
# Q-94824513                       Y             1.0
# Q-94825803                       Y             1.0
# Q-94826227                       Y             1.0
# Q-94828593                       Y             1.0
# Q-94849221                       Y             1.0
# Q-94850500                       Y             1.0
# Q-94850883                       N             1.0
# Q-94851198                       N             1.0
# Q-94853567                       Y             1.0
# Q-94858664                       Y             1.0
# Q-94860449                       Y             1.0
# Q-94862172                       Y             1.0
# Q-94864011                       Y             1.0
# Q-94867268                       Y             1.0
# Q-94882115                       Y             1.0
# Q-94886073                       N             1.0
# Q-94891737                       Y             1.0
# Q-94892338                       N             1.0
# Q-94899704                       Y             1.0
# Q-94902971                       Y             1.0
# Q-94907809                       Y             1.0
# Q-94912671                       N             1.0
# Q-94924989                       Y             1.0
# Q-94940213                       Y             1.0
# Q-94943846                       Y             1.0
# Q-94945717                       N             1.0
# Q-94977539                       Y             1.0
# T000078824                       Y             0.0
# T000079618                       Y             1.0
# T000080092                       N             1.0
#
# [19999 rows x 19 columns]

# %%
data.isnull().sum().sort_values(ascending=False)
# Out:
# UPGRADE_DATE                 889
# SITE_TYPE_DESC                74
# DIRECT_INDIRECT_CHANNEL       45
# MOST_RECENT_SALES_CHANNEL     28
# ACCOUNT_STATUS                16
# AGE                            9
# SITE_ACCOUNT_NUMBER            1
# SALES_SOURCE                   0
# SERVICE_PLAN                   0
# MODEL                          0
# SALES_CHANNEL                  0
# UPGRADE_STATUS                 0
# FEEDBACK                       0
# COMPUTER_OWNER                 0
# WARRANTY_NAME                  0
# GENDER                         0
# INCOME                         0
# MARITAL_STATUS                 0
# PRESENCE_OF_CHILDREN           0
# SATELLITE                      0
# dtype: int64

# %%
data=data.copy().dropna(how='any')
data.shape
# Out:
# (18954, 20)

# %%
data.update(data[(data['MARITAL_STATUS']=='.')].replace('.',0.0))

# %%
data.isnull().sum().sort_values(ascending=False)
# Out:
# UPGRADE_STATUS               0
# COMPUTER_OWNER               0
# ACCOUNT_STATUS               0
# UPGRADE_DATE                 0
# SERVICE_PLAN                 0
# MODEL                        0
# SALES_CHANNEL                0
# DIRECT_INDIRECT_CHANNEL      0
# SALES_SOURCE                 0
# FEEDBACK                     0
# SATELLITE                    0
# SITE_TYPE_DESC               0
# WARRANTY_NAME                0
# MOST_RECENT_SALES_CHANNEL    0
# GENDER                       0
# AGE                          0
# INCOME                       0
# MARITAL_STATUS               0
# PRESENCE_OF_CHILDREN         0
# SITE_ACCOUNT_NUMBER          0
# dtype: int64

# %%
columns=['SERVICE_PLAN','UPGRADE_STATUS','SALES_CHANNEL','DIRECT_INDIRECT_CHANNEL','MODEL','FEEDBACK','INCOME','GENDER','COMPUTER_OWNER','PRESENCE_OF_CHILDREN',]
for x in columns:
    print("\n","Relation between ",x," and Account Status")
    cross=pd.crosstab(data[x],data['ACCOUNT_STATUS'])
    print(cross)
    chi2=sp.chi2_contingency(cross)
    print('Chi2 statistic value is: ',chi2[0],"\n","Corresponding p-value is: ",chi2[1],"\n")
    print("+"*80)
# Out:
#  Relation between  SERVICE_PLAN  and Account Status
# ACCOUNT_STATUS     Active  Closed  Inactive
# SERVICE_PLAN
# Basic                1252     582         3
# Basic_Ltd            1260     612         3
# Elite                1248    3075         2
# Home                 1229    1009         3
# Power15                 0     562         0
# Power150             1239       0         0
# Pro                  1201     508         0
# Professional            0     574         0
# Professional Plus       0     465         0
# Proplus              2488     615         2
# SO                      0    1022         0
# Chi2 statistic value is:  6521.824473132226
#  Corresponding p-value is:  0.0
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
#  Relation between  UPGRADE_STATUS  and Account Status
# ACCOUNT_STATUS  Active  Closed  Inactive
# UPGRADE_STATUS
# 1.0               9917    9024        13
# Chi2 statistic value is:  0.0
#  Corresponding p-value is:  1.0
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
#  Relation between  SALES_CHANNEL  and Account Status
# ACCOUNT_STATUS  Active  Closed  Inactive
# SALES_CHANNEL
# Call Center       1370       0         1
# Call Centers         0    3694         0
# Retail/Others        0    1442         0
# Retail/others     1427       0         6
# Sales Agents      4327    1296         4
# Vars              1411    1263         0
# Web Orders           0    1329         0
# Web orders        1382       0         2
# Chi2 statistic value is:  12303.541387217974
#  Corresponding p-value is:  0.0
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
#  Relation between  DIRECT_INDIRECT_CHANNEL  and Account Status
# ACCOUNT_STATUS           Active  Closed  Inactive
# DIRECT_INDIRECT_CHANNEL
# 0                             9       0         0
# Direct                     2312    2525         3
# Indirect                   7596    6499        10
# Chi2 statistic value is:  61.84954986235432
#  Corresponding p-value is:  1.1848646358608793e-12
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
#  Relation between  MODEL  and Account Status
# ACCOUNT_STATUS  Active  Closed  Inactive
# MODEL
# DW4000             644    1388         0
# DW4020             647       0         7
# DW6000             511    1223         0
# DW7000             249    1360         1
# HN7000S           4921    1659         4
# HN9000            1975    3355         1
# UNK                970      39         0
# Chi2 statistic value is:  4877.431923530752
#  Corresponding p-value is:  0.0
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
#  Relation between  FEEDBACK  and Account Status
# ACCOUNT_STATUS  Active  Closed  Inactive
# FEEDBACK
# BAD               3026    6406         5
# GOOD              6891    2618         8
# Chi2 statistic value is:  3096.8216939194513
#  Corresponding p-value is:  0.0
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
#  Relation between  INCOME  and Account Status
# ACCOUNT_STATUS  Active  Closed  Inactive
# INCOME
# 0                 3025    1993         3
# 1                  156     206         0
# 2                  169     341         0
# 3                  666    1288         1
# 4                  954    1057         3
# 5                  871    1063         1
# 6                 1533    1003         0
# 7                 1006     386         1
# 8                  589     345         2
# 9                  461     213         2
# A                  190     544         0
# B                   43     138         0
# C                   98     177         0
# D                  156     270         0
# Chi2 statistic value is:  1289.6260315342884
#  Corresponding p-value is:  1.0052622912522179e-255
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
#  Relation between  GENDER  and Account Status
# ACCOUNT_STATUS  Active  Closed  Inactive
# GENDER
# 1.0               5990    5627         8
# 2.0               3927    3397         5
# Chi2 statistic value is:  7.6115561800479785
#  Corresponding p-value is:  0.022241884243180056
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
#  Relation between  COMPUTER_OWNER  and Account Status
# ACCOUNT_STATUS  Active  Closed  Inactive
# COMPUTER_OWNER
# N                 8801    2542        10
# Y                 1116    6482         3
# Chi2 statistic value is:  7219.559915114152
#  Corresponding p-value is:  0.0
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
#  Relation between  PRESENCE_OF_CHILDREN  and Account Status
# ACCOUNT_STATUS        Active  Closed  Inactive
# PRESENCE_OF_CHILDREN
# 0.0                     7897    5895        12
# 1.0                     2020    3129         1
# Chi2 statistic value is:  491.09068189218266
#  Corresponding p-value is:  2.2962193377455594e-107
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++

# %%
#Updating A,B,C,D,E in Income column with 11,12,13,14,15 for data
data.update(data[data['INCOME']=='A'].replace('A',11))
data.update(data[data['INCOME']=='B'].replace('B',12))
data.update(data[data['INCOME']=='C'].replace('C',13))
data.update(data[data['INCOME']=='D'].replace('D',14))
data.update(data[data['INCOME']=='E'].replace('E',15))

#Updating A,B,C,D,E in Income column with 11,12,13,14,15 for churneddata
churneddata.update(churneddata[churneddata['INCOME']=='A'].replace('A',11))
churneddata.update(churneddata[churneddata['INCOME']=='B'].replace('B',12))
churneddata.update(churneddata[churneddata['INCOME']=='C'].replace('C',13))
churneddata.update(churneddata[churneddata['INCOME']=='D'].replace('D',14))
churneddata.update(churneddata[churneddata['INCOME']=='E'].replace('E',15))

# %%
plt.figure(figsize=(15,7))
data['SERVICE_PLAN'].value_counts().plot.bar()
plt.title("SERVICE PLAN")
plt.xlabel("PLANS")
plt.ylabel("Number of Customers")
plt.grid()
plt.show()

# %%
plt.figure(figsize=(15,7))
data["MODEL"].value_counts().plot.bar()
plt.title("Model")
plt.xlabel("Plans")
plt.ylabel("Number of Customers")
plt.grid()
plt.show()

# %%
plt.figure(figsize=(15,7))
data["SALES_CHANNEL"].value_counts().plot.bar()
plt.title("Sales Channel")
plt.xlabel("Sales Channel")
plt.ylabel("Number of Customers")
plt.grid()
plt.show()

# %%
plt.figure(figsize=(15,7))
data["DIRECT_INDIRECT_CHANNEL"].value_counts().plot.bar()
plt.title("Channel")
plt.xlabel("Channel")
plt.ylabel("Number of Customers")
plt.grid()
plt.show()

# %%
plt.figure(figsize=(15,7))
data["SALES_SOURCE"].value_counts().plot.bar()
plt.title("SALES_SOURCE")
plt.xlabel("SALES_SOURCE")
plt.ylabel("Number of Customers")
plt.grid()
plt.show()

# %%
plt.figure(figsize=(15,7))
data["FEEDBACK"].value_counts().plot.bar()
plt.title("FEEDBACK")
plt.xlabel("FEEDBACK")
plt.ylabel("Number of Customers")
plt.grid()
plt.show()

# %%
plt.figure(figsize=(15,7))
data['SITE_TYPE_DESC'].value_counts().plot.bar()
plt.title("SITE_TYPE_DESC")
plt.xlabel("SITE_TYPE_DESC")
plt.ylabel("Number of Customers")
plt.grid()
plt.show()

# %%
plt.figure(figsize=(15,7))
data["WARRANTY_NAME"].value_counts().plot.bar()
plt.title("WARRANTY_NAME")
plt.xlabel("WARRANTY_NAME")
plt.ylabel("Number of Customers")
plt.grid()
plt.show()

# %%
plt.figure(figsize=(15,7))
data["MOST_RECENT_SALES_CHANNEL"].value_counts().plot.bar()
plt.title("MOST_RECENT_SALES_CHANNEL")
plt.xlabel("MOST_RECENT_SALES_CHANNEL")
plt.ylabel("Number of Customers")
plt.grid()
plt.show()

# %%
plt.figure(figsize=(15,7))
data['GENDER'].value_counts().plot.bar()
plt.title("GENDER")
plt.xlabel("GENDER")
plt.ylabel("Number of Customers")
plt.grid()
plt.show()

# %%
plt.figure(figsize=(15,7))
data['AGE'].value_counts().plot.bar()
plt.title("AGE")
plt.xlabel("AGE")
plt.ylabel("Number of Customers")
plt.grid()
plt.show()

# %%
plt.figure(figsize=(15,7))
data['INCOME'].value_counts().plot.bar()
plt.title("INCOME")
plt.xlabel("INCOME")
plt.ylabel("Number of Customers")
plt.grid()
plt.show()

# %%
plt.figure(figsize=(15,7))
data['MARITAL_STATUS'].value_counts().plot.bar()
plt.title("MARITAL_STATUS")
plt.xlabel("MARITAL_STATUS")
plt.ylabel("Number of Customers")
plt.grid()
plt.show()

# %%
plt.figure(figsize=(15,7))
data['PRESENCE_OF_CHILDREN'].value_counts().plot.bar()
plt.title("PRESENCE_OF_CHILDREN")
plt.xlabel("PRESENCE_OF_CHILDREN")
plt.ylabel("Number of Customers")
plt.grid()
plt.show()

# %%
plt.figure(figsize=(15,7))
data['COMPUTER_OWNER'].value_counts().plot.bar()
plt.title("COMPUTER_OWNER")
plt.xlabel("COMPUTER_OWNER")
plt.ylabel("Number of Customers")
plt.grid()
plt.show()

# %%
plt.figure(figsize=(15,7))
churneddata["COMPUTER_OWNER"].value_counts().plot.bar()
plt.title("COMPUTER_OWNER")
plt.xlabel("COMPUTER_OWNER")
plt.ylabel("Number of churned Customers")
plt.grid()
plt.show()

# %%
plt.figure(figsize=(15,7))
churneddata["MODEL"].value_counts().plot.bar()
plt.title("MODEL")
plt.xlabel("MODEL")
plt.ylabel("Number of churned Customers")
plt.grid()
plt.show()

# %%
plt.figure(figsize=(15,7))
churneddata["SERVICE_PLAN"].value_counts().plot.bar()
plt.title("SERVICE_PLAN")
plt.xlabel("SERVICE_PLAN")
plt.ylabel("Number of churned Customers")
plt.grid()
plt.show()

# %%
plt.figure(figsize=(15,7))
churneddata["WARRANTY_NAME"].value_counts().plot.bar()
plt.title("WARRANTY_NAME")
plt.xlabel("WARRANTY_NAME")
plt.ylabel("Number of churned Customers")
plt.grid()
plt.show()

# %%
plt.figure(figsize=(15,7))
churneddata["SALES_CHANNEL"].value_counts().plot.bar()
plt.title("SALES_CHANNEL")
plt.xlabel("SALES_CHANNEL")
plt.ylabel("Number of churned Customers")
plt.grid()
plt.show()

# %%
plt.figure(figsize=(15,7))
churneddata["FEEDBACK"].value_counts().plot.bar()
plt.title("FEEDBACK")
plt.xlabel("FEEDBACK")
plt.ylabel("Number of churned Customers")
plt.grid()
plt.show()

# %%
plt.figure(figsize=(15,7))
churneddata["AGE"].value_counts().plot.bar()
plt.title("AGE")
plt.xlabel("AGE")
plt.ylabel("Number of churned Customers")
plt.grid()
plt.show()

# %%
plt.figure(figsize=(15,7))
churneddata["SALES_SOURCE"].value_counts().plot.bar()
plt.title("SALES_SOURCE")
plt.xlabel("SALES_SOURCE")
plt.ylabel("Number of churned Customers")
plt.grid()
plt.show()

# %%
plt.figure(figsize=(15,7))
churneddata["INCOME"].value_counts().plot.bar()
plt.title("INCOME")
plt.xlabel("INCOME")
plt.ylabel("Number of churned Customers")
plt.grid()
plt.show()

# %%
plt.figure(figsize=(15,7))
churneddata["MOST_RECENT_SALES_CHANNEL"].value_counts().plot.bar()
plt.title("MOST_RECENT_SALES_CHANNEL")
plt.xlabel("MOST_RECENT_SALES_CHANNEL")
plt.ylabel("Number of customers Churned")
plt.grid()
plt.show()

# %%
plt.figure(figsize=(15,7))
churneddata["GENDER"].value_counts().plot.bar()
plt.title("Gender")
plt.xlabel("Gender")
plt.ylabel("Number of customers Churned")
plt.grid()
plt.show()

# %%
#Removing the redundant columns
data.drop(['SALES_SOURCE','SATELLITE','MOST_RECENT_SALES_CHANNEL'],axis=1,inplace=True)

# %%
#Extracting our target variable, ACCOUNT_STATUS as "y"
y=data['ACCOUNT_STATUS'].copy()

# %%
#Creating the dummy variables
temp=pd.get_dummies(data['COMPUTER_OWNER'],prefix='COMPUTER_OWNER')
data=data.join(temp)

temp=pd.get_dummies(data['SERVICE_PLAN'],prefix='SERVICE_PLAN')
data=data.join(temp)

temp=pd.get_dummies(data['MODEL'],prefix='MODEL')
data=data.join(temp)

temp=pd.get_dummies(data['SALES_CHANNEL'],prefix='SALES_CHANNEL')
data=data.join(temp)

temp=pd.get_dummies(data['DIRECT_INDIRECT_CHANNEL'],prefix='DIRECT_INDIRECT_CHANNEL')
data=data.join(temp)

temp=pd.get_dummies(data['SITE_TYPE_DESC'],prefix='SITE_TYPE_DESC')
data=data.join(temp)

temp=pd.get_dummies(data['WARRANTY_NAME'],prefix='WARRANTY_NAME')
data=data.join(temp)

temp=pd.get_dummies(data['FEEDBACK'],prefix='FEEDBACK')
data=data.join(temp)

# %%
#Removing columns for which dummy variables have been created
data.drop(['FEEDBACK','COMPUTER_OWNER','ACCOUNT_STATUS','SERVICE_PLAN','MODEL','SALES_CHANNEL','DIRECT_INDIRECT_CHANNEL','SITE_TYPE_DESC','WARRANTY_NAME'],axis=1,inplace=True)

# %%
data.AGE=data.AGE.replace('.',data[~(data.AGE==".")].AGE.mean())

# %%
data["SALES_CHANNEL_Retail/Others"]=data["SALES_CHANNEL_Retail/Others"]+data["SALES_CHANNEL_Retail/Others"]
data["SALES_CHANNEL_Web Orders"]=data["SALES_CHANNEL_Web Orders"]+data["SALES_CHANNEL_Web orders"]

# %%
data=data.drop(columns=["SALES_CHANNEL_Retail/others","SALES_CHANNEL_Web orders","SITE_ACCOUNT_NUMBER","UPGRADE_DATE"])

# %%
#Replacing "Active" status with 1 and "Closed"/"Inactive" with 2 for the target variable
y=y.replace('Active',1)
y=y.replace('Closed',2)
y=y.replace('Inactive',2) #Since number of inactive accounts very few hence including them with closed accounts

# %%
#Modeling

# %%
x_train, x_test, y_train, y_test= train_test_split(data,y,test_size=0.2,random_state=0)

# %%
names=[
    "Nearest Neighbors", 
    "Linear SVM", 
    "RBF SVM", 
    "Decision Tree",
    "Random Forest", 
    "AdaBoost",
    "Linear Discriminant Analysis",
    "Logistic Regression"
    ]

classifiers=[
    KNeighborsClassifier(),
    SVC(kernel="linear", C=0.025),
    SVC(gamma='auto', C=1),
    DecisionTreeClassifier(max_depth=5),
    RandomForestClassifier(max_depth=5, n_estimators=500),
    AdaBoostClassifier(),
    LinearDiscriminantAnalysis(),
    LogisticRegression()
    ]

# %%
for i,j in zip(names,classifiers):
    j.fit(x_train,y_train)
    
    score = j.score(x_test,y_test)
    ypred=j.predict(x_test)    
    cv_acc=cross_val_score(estimator=j,X=x_train,y=y_train,cv=5)
    cm=confusion_matrix(y_test,ypred)
    cv_acc=cv_acc.mean()
    acc=accuracy_score(y_test,ypred)
        
    print("+"*100)
    print("\n Classifier is \n" + str(i))
    print("\n Score \n" + str(score*100) + "%")
    print('\n Confusion Matrix \n',cm)
    print('\n Cross Validation Score \n',cv_acc)
    print('\n Testing Accuracy \n',acc)
    
    if i=="AdaBoost":
        feature_importances=pd.DataFrame(j.feature_importances_,index = x_train.columns,columns=['importance']).sort_values('importance',ascending=False)
        print(feature_importances)
# Out:
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
#  Classifier is
# Nearest Neighbors
#
#  Score
# 91.34792930625166%
#
#  Confusion Matrix
#  [[1844   99]
#  [ 229 1619]]
#
#  Cross Validation Score
#  0.9122871334054098
#
#  Testing Accuracy
#  0.9134792930625165
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
#  Classifier is
# Linear SVM
#
#  Score
# 95.62120812450542%
#
#  Confusion Matrix
#  [[1889   54]
#  [ 112 1736]]
#
#  Cross Validation Score
#  0.9537694836616856
#
#  Testing Accuracy
#  0.9562120812450541
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
#  Classifier is
# RBF SVM
#
#  Score
# 95.19915589554208%
#
#  Confusion Matrix
#  [[1875   68]
#  [ 114 1734]]
#
#  Cross Validation Score
#  0.9504064767378478
#
#  Testing Accuracy
#  0.9519915589554208
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
#  Classifier is
# Decision Tree
#
#  Score
# 91.92825112107623%
#
#  Confusion Matrix
#  [[1799  144]
#  [ 162 1686]]
#
#  Cross Validation Score
#  0.9151224792976151
#
#  Testing Accuracy
#  0.9192825112107623
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
#  Classifier is
# Random Forest
#
#  Score
# 91.92825112107623%
#
#  Confusion Matrix
#  [[1806  137]
#  [ 169 1679]]
#
#  Cross Validation Score
#  0.9246857535328694
#
#  Testing Accuracy
#  0.9192825112107623
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
#  Classifier is
# AdaBoost
#
#  Score
# 95.80585597467687%
#
#  Confusion Matrix
#  [[1886   57]
#  [ 102 1746]]
#
#  Cross Validation Score
#  0.9612875329475408
#
#  Testing Accuracy
#  0.9580585597467687
#                                                     importance
# INCOME                                                    0.10
# AGE                                                       0.10
# SALES_CHANNEL_Web Orders                                  0.08
# SALES_CHANNEL_Vars                                        0.06
# SALES_CHANNEL_Call Center                                 0.06
# MODEL_UNK                                                 0.04
# SERVICE_PLAN_Elite                                        0.04
# SALES_CHANNEL_Sales Agents                                0.04
# MODEL_HN7000S                                             0.04
# SERVICE_PLAN_Proplus                                      0.04
# FEEDBACK_GOOD                                             0.04
# MARITAL_STATUS                                            0.02
# MODEL_DW7000                                              0.02
# SITE_TYPE_DESC_Broadband Remote                           0.02
# SERVICE_PLAN_Power15                                      0.02
# PRESENCE_OF_CHILDREN                                      0.02
# SALES_CHANNEL_Retail/Others                               0.02
# SALES_CHANNEL_Call Centers                                0.02
# COMPUTER_OWNER_Y                                          0.02
# WARRANTY_NAME_EXPRESS REPAIR BASIC                        0.02
# SERVICE_PLAN_Basic                                        0.02
# WARRANTY_NAME_SRVC ASSUR STD NEW CUST                     0.02
# MODEL_DW4020                                              0.02
# MODEL_DW4000                                              0.02
# SERVICE_PLAN_SO                                           0.02
# SERVICE_PLAN_Basic_Ltd                                    0.02
# SERVICE_PLAN_Professional Plus                            0.02
# SERVICE_PLAN_Professional                                 0.02
# SERVICE_PLAN_Power150                                     0.02
# WARRANTY_NAME_Spaceway                                    0.00
# WARRANTY_NAME_SRVC ASSUR STD EXISTING CUST NO C...        0.00
# WARRANTY_NAME_SRVC ASSUR PLUS NEW CUST                    0.00
# FEEDBACK_BAD                                              0.00
# WARRANTY_NAME_EXPRESS REPAIR HOME WITH TERM               0.00
# WARRANTY_NAME_EXPRESS REPAIR HOME WITH COMMITME...        0.00
# WARRANTY_NAME_EXPRESS REPAIR HOME W/O COMMITMEN...        0.00
# WARRANTY_NAME_EXPRESS REPAIR HOME                         0.00
# WARRANTY_NAME_EXPRESS REPAIR BUSINESS WITH TERM           0.00
# SERVICE_PLAN_Home                                         0.00
# WARRANTY_NAME_Broadband Remote                            0.00
# WARRANTY_NAME_0                                           0.00
# SITE_TYPE_DESC_Spaceway                                   0.00
# DIRECT_INDIRECT_CHANNEL_Indirect                          0.00
# DIRECT_INDIRECT_CHANNEL_Direct                            0.00
# DIRECT_INDIRECT_CHANNEL_0                                 0.00
# UPGRADE_STATUS                                            0.00
# COMPUTER_OWNER_N                                          0.00
# MODEL_HN9000                                              0.00
# MODEL_DW6000                                              0.00
# SERVICE_PLAN_Pro                                          0.00
# GENDER                                                    0.00
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
#  Classifier is
# Linear Discriminant Analysis
#
#  Score
# 95.17277763123187%
#
#  Confusion Matrix
#  [[1896   47]
#  [ 136 1712]]
#
#  Cross Validation Score
#  0.9515933333355088
#
#  Testing Accuracy
#  0.9517277763123186
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
#  Classifier is
# Logistic Regression
#
#  Score
# 95.67396465312582%
#
#  Confusion Matrix
#  [[1881   62]
#  [ 102 1746]]
#
#  Cross Validation Score
#  0.9601665741508534
#
#  Testing Accuracy
#  0.9567396465312582

# %%
#As observed, here AdaBoost yields best accuracy. Accordingly, we have the corresponding feature importances above.
#According to the mentioned importance, we can alter the number of features to make the model better.

# %%
data=data[["INCOME","AGE","SALES_CHANNEL_Web Orders","SALES_CHANNEL_Vars","SALES_CHANNEL_Call Center","MODEL_UNK","SERVICE_PLAN_Elite","SALES_CHANNEL_Sales Agents","MODEL_HN7000S","SERVICE_PLAN_Proplus","FEEDBACK_GOOD","MARITAL_STATUS","MODEL_DW7000","SITE_TYPE_DESC_Spaceway","SERVICE_PLAN_Power15","PRESENCE_OF_CHILDREN","SALES_CHANNEL_Retail/Others","SALES_CHANNEL_Call Centers","COMPUTER_OWNER_Y","WARRANTY_NAME_EXPRESS REPAIR BASIC","SERVICE_PLAN_Basic","WARRANTY_NAME_SRVC ASSUR STD NEW CUST","MODEL_DW4020","MODEL_DW4000","SERVICE_PLAN_SO","SERVICE_PLAN_Basic_Ltd","SERVICE_PLAN_Professional Plus","SERVICE_PLAN_Professional","SERVICE_PLAN_Power150"]]

# %%
#Re-Modeling
x_train,x_test,y_train,y_test=train_test_split(data,y,test_size=0.2,random_state=0)

# %%
model=AdaBoostClassifier()
model.fit(x_train,y_train)
score = model.score(x_test,y_test)
feature_importances=pd.DataFrame(model.feature_importances_,index = x_train.columns,columns=['importance']).sort_values('importance',ascending=False)
print("Score \n" + str(score*100) + "%")
print(feature_importances)
# Out:
# Score
# 95.80585597467687%
#                                        importance
# INCOME                                       0.10
# AGE                                          0.10
# SALES_CHANNEL_Web Orders                     0.08
# SALES_CHANNEL_Vars                           0.06
# SALES_CHANNEL_Call Center                    0.06
# MODEL_HN7000S                                0.04
# FEEDBACK_GOOD                                0.04
# SERVICE_PLAN_Proplus                         0.04
# SALES_CHANNEL_Sales Agents                   0.04
# SERVICE_PLAN_Elite                           0.04
# MODEL_UNK                                    0.04
# SERVICE_PLAN_Basic                           0.02
# SERVICE_PLAN_Professional                    0.02
# SERVICE_PLAN_Professional Plus               0.02
# SERVICE_PLAN_Basic_Ltd                       0.02
# SERVICE_PLAN_SO                              0.02
# MODEL_DW4000                                 0.02
# MODEL_DW4020                                 0.02
# WARRANTY_NAME_SRVC ASSUR STD NEW CUST        0.02
# SERVICE_PLAN_Power15                         0.02
# WARRANTY_NAME_EXPRESS REPAIR BASIC           0.02
# COMPUTER_OWNER_Y                             0.02
# SALES_CHANNEL_Call Centers                   0.02
# SALES_CHANNEL_Retail/Others                  0.02
# PRESENCE_OF_CHILDREN                         0.02
# SITE_TYPE_DESC_Spaceway                      0.02
# MODEL_DW7000                                 0.02
# MARITAL_STATUS                               0.02
# SERVICE_PLAN_Power150                        0.02

# %%
#Insights:
#1. Maximum number of customers have Service plan Elite, followed by Proplus.
#Churn for Elite customers are at least 2.5 times more as compared to any other Service plan. 

#2. Sales Agents are the Sales Channel for maximum customer base,
#though maximum churn is observed for customers acquired via Call Centres.

#3. We've received equal number of good and bad feedback reviews, though,
#as obvious, churn for people with bad feedback are a lot more than people exiting with a good feedback.

#4. The number of Male customers is almost 1.5 times more in comparison to female customers.

#5. Maximum customers have an annual income less than $10K.

#6. Maximum number of customers do not have children.

#7. About 60% customers do not Own Computer; Churn rate observed for customers 
#with computers is almost 2.5 times the number of customers who do not own computers.
